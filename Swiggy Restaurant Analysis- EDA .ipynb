# %% [markdown]
# # Importing Libraries and Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
# !pip install -U kaleido
# Out:
# ...
#   Obtaining dependency information for kaleido from https://files.pythonhosted.org/packages/28/0e/853df00cac4823eaa8f35114d0d0ad1e2ec6b8243ce4acf5f8ac5235c517/kaleido-1.0.0-py3-none-any.whl.metadata
#   Using cached kaleido-1.0.0-py3-none-any.whl.metadata (5.6 kB)
# ...
# Using cached kaleido-1.0.0-py3-none-any.whl (51 kB)
# ...
# WARNING: Ignoring invalid distribution ~aleido (C:\Users\hp\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~aleido (C:\Users\hp\anaconda3\Lib\site-packages)

# %%
df=pd.read_csv('C:/Users/hp/Downloads/swiggy/swiggy.csv')
df
# Out:
#           ID                    Area       City                Restaurant  \
# 0        211             Koramangala  Bangalore               Tandoor Hut
# 1        221             Koramangala  Bangalore             Tunday Kababi
# 2        246               Jogupalya  Bangalore                   Kim Lee
# 3        248             Indiranagar  Bangalore         New Punjabi Hotel
# 4        249             Indiranagar  Bangalore                       Nh8
# ...      ...                     ...        ...                       ...
# 8675  464626  Panjarapole Cross Road  Ahmedabad                Malt Pizza
# 8676  465835                  Rohini      Delhi  Jay Mata Ji Home Kitchen
# 8677  465872                  Rohini      Delhi      Chinese Kitchen King
# 8678  465990                  Rohini      Delhi    Shree Ram Paratha Wala
# 8679  466488             Navrangpura  Ahmedabad              Sassy Street
#
#       Price  Avg ratings  Total ratings  \
# ...

# %% [markdown]
# # Exploring Data

# %%
df.describe()
# Out:
#                   ID        Price  Avg ratings  Total ratings  Delivery time
# count    8680.000000  8680.000000  8680.000000    8680.000000    8680.000000
# mean   244812.071429   348.444470     3.655104     156.634793      53.967051
# std    158671.617188   230.940074     0.647629     391.448014      14.292335
# min       211.000000     0.000000     2.000000      20.000000      20.000000
# 25%     72664.000000   200.000000     2.900000      50.000000      44.000000
# 50%    283442.000000   300.000000     3.900000      80.000000      53.000000
# 75%    393425.250000   400.000000     4.200000     100.000000      64.000000
# max    466928.000000  2500.000000     5.000000   10000.000000     109.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8680 entries, 0 to 8679
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ID             8680 non-null   int64
#  1   Area           8680 non-null   object
#  2   City           8680 non-null   object
#  3   Restaurant     8680 non-null   object
#  4   Price          8680 non-null   float64
#  5   Avg ratings    8680 non-null   float64
#  6   Total ratings  8680 non-null   int64
#  7   Food type      8680 non-null   object
#  8   Address        8680 non-null   object
#  9   Delivery time  8680 non-null   int64
# dtypes: float64(2), int64(3), object(5)
# memory usage: 678.3+ KB

# %%
df.isnull().sum()
# Out:
# ID               0
# Area             0
# City             0
# Restaurant       0
# Price            0
# Avg ratings      0
# Total ratings    0
# Food type        0
# Address          0
# Delivery time    0
# dtype: int64

# %%
df10=df.drop('ID',axis=1)

# %%
df10['City'].value_counts()
# Out:
# Kolkata      1346
# Mumbai       1277
# Chennai      1106
# Pune         1090
# Hyderabad    1075
# Bangalore     946
# Ahmedabad     717
# Delhi         611
# Surat         512
# Name: City, dtype: int64

# %%
df10['Price']=pd.to_numeric(df['Price'],errors='coerce')
df10['Avg ratings']=pd.to_numeric(df['Avg ratings'],errors='coerce')
df10['Delivery time']=pd.to_numeric(df['Delivery time'],errors='coerce')

# %%
df10[df10['City']=='Bangalore']['Area'].value_counts()
# Out:
# Indiranagar                  130
# Koramangala                  124
# Ashok Nagar                  113
# Central Bangalore             71
# Basavanagudi                  54
#                             ...
# Central Banglore               1
# Jayamahal                      1
# Commercial Street              1
# Cooke Town                     1
# Sanjay Nagar New Bel Road      1
# Name: Area, Length: 77, dtype: int64

# %%
df10.groupby('City')['Delivery time'].mean().sort_values()
# Out:
# City
# Ahmedabad    44.709902
# Mumbai       48.318716
# Surat        48.484375
# Hyderabad    49.933023
# Bangalore    50.529598
# Delhi        50.734861
# Pune         55.854128
# Chennai      58.968354
# Kolkata      67.809807
# Name: Delivery time, dtype: float64

# %%
df10.groupby('Area')['Delivery time'].mean().sort_values()
# Out:
# Area
# Venkateshwara Colony          24.0
# Moonlight Cream Sagrampura    26.0
# Ramkote                       26.0
# Rajamohallah                  27.0
# Sector 4 Rohini               27.0
#                               ...
# Smarpally Kestopur            90.0
# Tollygunge                    90.7
# Haltu                         91.0
# Santoshpur                    92.0
# Rabindrapally                 97.0
# Name: Delivery time, Length: 833, dtype: float64

# %%
df10.corr()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_7004\1694334785.py:1: FutureWarning:
#
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#                   Price  Avg ratings  Total ratings  Delivery time
# Price          1.000000     0.113630      -0.014672       0.076009
# Avg ratings    0.113630     1.000000       0.157900      -0.146987
# Total ratings -0.014672     0.157900       1.000000      -0.084090
# Delivery time  0.076009    -0.146987      -0.084090       1.000000

# %%
df10.groupby('Area')['Price'].mean().sort_values()
# Out:
# Area
# Ghodasar                          0.0
# Sri Durga Enclave                65.0
# Sanjay Nagar New Bel Road        75.0
# Bangur                           98.0
# Tad Bun                         100.0
#                                 ...
# Central Market Punjabi Bagh    1050.0
# Brigade Road                   1100.0
# Pacific Mall Subhash Nagar     1200.0
# Someshwarpura                  1200.0
# Vile Parle                     1500.0
# Name: Price, Length: 833, dtype: float64

# %% [markdown]
# # EDA

# %%
df5=df10['City'].value_counts().head(10)
fig=px.bar(df5)
fig.show()
fig.write_image("Cities.png")
# Out:
# <div>                            <div id="fffb9c03-22ea-4efc-8130-7fb949b1241a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fffb9c03-22ea-4efc-8130-7fb949b1241a")) {                    Plotly.newPlot(                        "fffb9c03-22ea-4efc-8130-7fb949b1241a",                        [{"alignmentgroup":"True","hovertemplate":"variable=City<br>index=%{x}<br>value=%{y}<extra></extra>","legendgroup":"City","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"City","offsetgroup":"City","orientation":"v","showlegend":true,"textposition":"auto","x":["Kolkata","Mumbai","Chennai","Pune","Hyderabad","Bangalore","Ahmedabad","Delhi","Surat"],"xaxis":"x","y":[1346,1277,1106,1090,1075,946,717,611,512],"yaxis":"y","type":"bar"}],                     
# ...

# %%
df6=df10[df10['City']=='Bangalore']['Area'].value_counts().head(10)
fig=px.bar(df6)
fig.show()
fig.write_image("City(Banglore).png")
# Out:
# <div>                            <div id="d04b242f-7170-410c-8547-bffc93cec6d0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d04b242f-7170-410c-8547-bffc93cec6d0")) {                    Plotly.newPlot(                        "d04b242f-7170-410c-8547-bffc93cec6d0",                        [{"alignmentgroup":"True","hovertemplate":"variable=Area<br>index=%{x}<br>value=%{y}<extra></extra>","legendgroup":"Area","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Area","offsetgroup":"Area","orientation":"v","showlegend":true,"textposition":"auto","x":["Indiranagar","Koramangala","Ashok Nagar","Central Bangalore","Basavanagudi","Jayanagar","Malleshwaram","Rajajinagar","Domlur","Pulikeshi Nagar"],"xaxis":"x","y":[130,124,113,71,54,49,47,38,21,21]
# ...

# %%
plt.figure(figsize=(10,10))
fig=px.scatter(df10,x='Price',y='Avg ratings',color='City')
fig.show()
fig.write_image("price vs ratings.png")
# Out:
# <div>                            <div id="4829fd54-7a77-41b5-a893-436957dbd197" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4829fd54-7a77-41b5-a893-436957dbd197")) {                    Plotly.newPlot(                        "4829fd54-7a77-41b5-a893-436957dbd197",                        [{"hovertemplate":"City=Bangalore<br>Price=%{x}<br>Avg ratings=%{y}<extra></extra>","legendgroup":"Bangalore","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Bangalore","showlegend":true,"x":[300.0,300.0,650.0,250.0,350.0,800.0,1000.0,150.0,350.0,300.0,400.0,250.0,532.0,500.0,150.0,290.0,300.0,250.0,800.0,1200.0,250.0,900.0,200.0,250.0,300.0,300.0,500.0,450.0,300.0,1000.0,300.0,550.0,450.0,200.0,300.0,200.0,400.0,500.0,450.0,500.0,500.0,110
# ...

# %%
df1=df10.groupby('City')['Delivery time'].mean().sort_values()
fig=px.bar(df1)
fig.show()
fig.write_image("City vs Delivery Time.png")
# Out:
# <div>                            <div id="fb7e9d08-9e7e-4314-9839-d10e31433319" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fb7e9d08-9e7e-4314-9839-d10e31433319")) {                    Plotly.newPlot(                        "fb7e9d08-9e7e-4314-9839-d10e31433319",                        [{"alignmentgroup":"True","hovertemplate":"variable=Delivery time<br>City=%{x}<br>value=%{y}<extra></extra>","legendgroup":"Delivery time","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Delivery time","offsetgroup":"Delivery time","orientation":"v","showlegend":true,"textposition":"auto","x":["Ahmedabad","Mumbai","Surat","Hyderabad","Bangalore","Delhi","Pune","Chennai","Kolkata"],"xaxis":"x","y":[44.709902370990235,48.31871574001566,48.484375,49.93302
# ...

# %%
df1=df10.groupby('Area')['Delivery time'].mean().sort_values()
fig=px.bar(df1)
fig.show()
fig.write_image("Area vs Delivery Time.png")
# Out:
# <div>                            <div id="561b2bbc-8c6e-4083-a060-0b495d5cc8f0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("561b2bbc-8c6e-4083-a060-0b495d5cc8f0")) {                    Plotly.newPlot(                        "561b2bbc-8c6e-4083-a060-0b495d5cc8f0",                        [{"alignmentgroup":"True","hovertemplate":"variable=Delivery time<br>Area=%{x}<br>value=%{y}<extra></extra>","legendgroup":"Delivery time","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Delivery time","offsetgroup":"Delivery time","orientation":"v","showlegend":true,"textposition":"auto","x":["Venkateshwara Colony","Moonlight Cream Sagrampura","Ramkote","Rajamohallah","Sector 4 Rohini","Chanchalguda","Sector 6 Rohini","Majura Gate","Sector 1 Rohini","
# ...

# %%
import plotly.graph_objects as go
correlation_matrix=df10.corr()
fig=go.Figure(data=go.Heatmap(z=correlation_matrix,x=correlation_matrix.columns,y=correlation_matrix.columns))
fig.show()
fig.write_image("Correlation.png")
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_7004\4018134652.py:2: FutureWarning:
#
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# ...

# %%
df6=df10.groupby('Area')['Price'].mean().sort_values().head(15)
fig=px.bar(df6)
fig.show()
fig.write_image("Area vs Price.png")
# Out:
# <div>                            <div id="f9ba14fa-b1c4-4c26-9d43-61ba365927b7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f9ba14fa-b1c4-4c26-9d43-61ba365927b7")) {                    Plotly.newPlot(                        "f9ba14fa-b1c4-4c26-9d43-61ba365927b7",                        [{"alignmentgroup":"True","hovertemplate":"variable=Price<br>Area=%{x}<br>value=%{y}<extra></extra>","legendgroup":"Price","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Price","offsetgroup":"Price","orientation":"v","showlegend":true,"textposition":"auto","x":["Ghodasar","Sri Durga Enclave","Sanjay Nagar New Bel Road","Bangur","Tad Bun","Valasaravakkam","Picnic Garden","Garodia Nagar","Padma Nagar Colony","Kadugondanahalli","Amarpalli","Ambegaon","3R
# ...

# %%
ratings_higherthan45 = df10[df10['Avg ratings'] > 4.5]
ratings_lowerthan45 = df10[df10['Avg ratings'] <= 4.5]

perce_above45 = len(ratings_higherthan45) / len(df10) * 100
perce_below45 = 100 - perce_above45

rating_df = pd.DataFrame({
    'Rating': ['Above 4.5', '4.5 and Below'],
    'Percentage': [perce_above45, perce_below45]
})

fig = px.pie(rating_df, names='Rating', values='Percentage',
             title='Distribution of Ratings')
fig.show()
fig.write_image("Distribution of ratings.png")
# Out:
# <div>                            <div id="da834516-56cd-42b8-8ffe-19eefa06943c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("da834516-56cd-42b8-8ffe-19eefa06943c")) {                    Plotly.newPlot(                        "da834516-56cd-42b8-8ffe-19eefa06943c",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Rating=%{label}<br>Percentage=%{value}<extra></extra>","labels":["Above 4.5","4.5 and Below"],"legendgroup":"","name":"","showlegend":true,"values":[3.7327188940092166,96.26728110599079],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222
# ...
